# %% [markdown]
# api@covidactnow.org
# Current data for all states

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import api_key

# %%
target_url = f"https://api.covidactnow.org/v2/states.json?apiKey={api_key}"
data = requests.get(target_url).json()
# data = response.json()

# %%
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "actuals": {
#             "cases": 69826,
#             "contactTracers": 235,
#             "deaths": 352,
#             "hospitalBeds": {
#                 "capacity": 1853,
#                 "currentUsageCovid": 18,
#                 "currentUsageTotal": 1091,
#                 "typicalUsageRate": 0.58
#             },
#             "icuBeds": {
#                 "capacity": 132,
#                 "currentUsageCovid": 5,
#                 "currentUsageTotal": 99,
#                 "typicalUsageRate": 0.676923076923
#             },
#             "negativeTests": 2297258,
#             "newCases": 53,
#             "newDeaths": 0,
#             "positiveTests": 112249,
#             "vaccinationsCompleted": 289158,
#             "vaccinationsInitiated": 339124,
#             "vaccinationsInitiatedDemographics": null,
#             "vaccinesAdministered": 614726,
#             "vaccinesAdministeredDemographics": null,
#             "vaccinesDistributed": 810945
# ...

# %%
i = []

# %%
for i in data["state"][0]:
    curr_state = requests.get(state).json()
    i.append(curr_state)
    
# print(state)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-f580e595db38> in <module>
# ----> 1 for i in data["state"][0]:
#       2     curr_state = requests.get(state).json()
#       3     i.append(curr_state)
#       4
#       5 # print(state)
#
# TypeError: list indices must be integers or slices, not str
