# %%
#set up
# %matplotlib notebook

# %%
#dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#data
combined_df = pd.read_csv('combined_data.csv')
combined_df.head()
# Out:
#        Country  Deaths to 5/1/21  Deaths Ratio by population  \
# 0  Afghanistan              2631                    0.006916
# 1      Albania              2396                    0.083947
# 2      Algeria              3261                    0.007574
# 3      Andorra               125                    0.162039
# 4       Angola               600                    0.001885
#
#    Vaccine Type Count  Reported Full Vacs  full Vac by population Code  \
# 0                 3.0             55624.0                0.146218  AFG
# 1                 4.0            228756.0                8.014740  ALB
# 2                 0.0                 0.0                0.000000  DZA
# 3                 2.0              4702.0                6.095253  AND
# 4                 1.0             75215.0                0.236337  AGO
#
#    2019 Population      2019 GDP     percapita
# 0         38041754   19291104008    507.103432
# 1          2854191   15279183290   5353.244856
# ...

# %%
#plot
ax = combined_df.plot(kind="scatter", x="percapita", y="full Vac by population", grid=True, figsize=(8,4),
              title="FullVac ratio to population percapita, Deaths(s), Vaccine(c)", s=combined_df["Deaths Ratio by population"]*100, c=combined_df["Vaccine Type Count"], colormap='jet')
ax.set_xscale('log')
plt.xlim([100,1000000])
plt.ylim([-5,80])
plt.show()
#plt.savefig("scatter_color_vacs.png")
# Out:
# <img src="data:image/png;base64,..." width="800">
